# %%
import pandas as pd
import colour_comp as cp

# %% [markdown]
# # Object Pipeline

# %% [markdown]
# ## Image to Image

# %%
image1dir = "IMG_2281"
image2dir = "IMG_65565

#Cant implicty grab the file extension
baseImg1 = image1dir + "/" + image1dir + ".JPEG"
baseImg2 = image2dir + "/" + image2dir + ".JPEG"

img1Df = pd.read_json(image1dir + "/" + image1dir + "_feature_df.json")
img2Df = pd.read_json(image2dir + "/" + image2dir + "_feature_df.json")

img1Df

# %% [markdown]
# ### Presence

# %%
image1dir = "IMG_2281"
image2dir = "IMG_6556"

def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0

    #Cant implicty grab the file extension
    baseImg1 = imgdir1 + "/" + imgdir1 + ".JPEG"
    baseImg2 = imgdir2 + "/" + imgdir2 + ".JPEG"

    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    img1DfOrderedLablesAsc = img1Df.sort_values(by='label', ascending=True)['label']
    img2DfOrderedLablesAsc = img2Df.sort_values(by='label', ascending=True)['label']

    img1LabelAscCounts = img1DfOrderedLablesAsc.value_counts()
    img2LabelAscCounts = img2DfOrderedLablesAsc.value_counts()

    common_lables = img1LabelAscCounts.index.intersection(img2LabelAscCounts.index)

    for value in common_lables:
        count1 = img1LabelAscCounts[value]
        count2 = img2LabelAscCounts[value]
        if count1 == count2:
            comp_score += 1

    print(comp_score)

    print(img1LabelAscCounts)
    print(img2LabelAscCounts)
            
    
    


    
comp_img_2_img(image1dir,image2dir)

# %% [markdown]
# ### Placement

# %%
image1dir = "IMG_2281"
image2dir = "IMG_6556"

def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0

    #Cant implicty grab the file extension
    baseImg1 = imgdir1 + "/" + imgdir1 + ".JPEG"
    baseImg2 = imgdir2 + "/" + imgdir2 + ".JPEG"

    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    for i in range(0,len(img1Df)-1):
        for j in range(0,len(img2Df)-1):
            if get_obj_placment(img1Df,i) == get_obj_placment(img2Df,j):
                print("full match ")
                comp_score +=1
            elif get_obj_placment(img1Df,i) == get_obj_placment(img2Df,j)[::-1]:
                print("reverse full match ")
                comp_score +=1
            


    print(get_obj_placment(img1Df,7))
    print(get_obj_placment(img2Df,5))

def get_obj_placment(df,x):
    if(x == 0):
        return (0,(df.iloc[x]['label']),(df.iloc[x+1]['label']))
    elif (x == len(df)-1):
        return ((df.iloc[x-1]['label']),(df.iloc[x]['label']),0)
    else:
        return (df.iloc[x-1]['label'],(df.iloc[x]['label']),(df.iloc[x+1]['label']))

comp_img_2_img(image1dir,image2dir)

# %% [markdown]
# ### Sky

# %%
image1dir = "IMG_2281"
image2dir = "IMG_6556"

def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0

    #Cant implicty grab the file extension
    baseImg1 = imgdir1 + "/" + imgdir1 + ".JPEG"
    baseImg2 = imgdir2 + "/" + imgdir2 + ".JPEG"

    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    sky1Index = img1Df[img1Df['image'].str.split('_').str[0] == 'sky'].index
    sky2Index = img2Df[img2Df['image'].str.split('_').str[0] == 'sky'].index


    skyimg1=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[sky1Index]['image']
    skyimg2=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[sky2Index]['image']
    sky1=skyimg1.values[0]
    sky2=skyimg2.values[0]
    print(type(skyimg1.values[0]))
    print(skyimg2)

    print(cp.get_distance(sky1,sky2))

    print(cp.hist_color_intersect(sky1,sky2))

    print(cp.lab_space_comp_percentage(sky1,sky2))

comp_img_2_img(image1dir,image2dir)

# %% [markdown]
# ## Final img_2_img

# %%
image1dir = "IMG_2281"
image2dir = "IMG_6556"

def get_obj_placment(df,x):
    if(x == 0):
        return (0,(df.iloc[x]['label']),(df.iloc[x+1]['label']))
    elif (x == len(df)-1):
        return ((df.iloc[x-1]['label']),(df.iloc[x]['label']),0)
    else:
        return (df.iloc[x-1]['label'],(df.iloc[x]['label']),(df.iloc[x+1]['label']))


def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0

    #Cant implicty grab the file extension
    baseImg1 = imgdir1 + "/" + imgdir1 + ".JPEG"
    baseImg2 = imgdir2 + "/" + imgdir2 + ".JPEG"

    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    img1DfOrderedLablesAsc = img1Df.sort_values(by='label', ascending=True)['label']
    img2DfOrderedLablesAsc = img2Df.sort_values(by='label', ascending=True)['label']

    img1LabelAscCounts = img1DfOrderedLablesAsc.value_counts()
    img2LabelAscCounts = img2DfOrderedLablesAsc.value_counts()

    common_lables = img1LabelAscCounts.index.intersection(img2LabelAscCounts.index)

    for value in common_lables:
        count1 = img1LabelAscCounts[value]
        count2 = img2LabelAscCounts[value]
        if count1 == count2:
            comp_score += 1

    
    for i in range(0,len(img1Df)-1):
        for j in range(0,len(img2Df)-1):
            if get_obj_placment(img1Df,i) == get_obj_placment(img2Df,j):
                comp_score +=1
            elif get_obj_placment(img1Df,i) == get_obj_placment(img2Df,j)[::-1]:
                
                comp_score +=1

    sky1Index = img1Df[img1Df['image'].str.split('_').str[0] == 'sky'].index
    sky2Index = img2Df[img2Df['image'].str.split('_').str[0] == 'sky'].index


    skyimg1=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[sky1Index]['image']
    skyimg2=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[sky2Index]['image']
    sky1=skyimg1.values[0]
    sky2=skyimg2.values[0]


    ##Can always edit these later
    if cp.get_distance(sky1,sky2) < 0.2:
        comp_score +=1

    if cp.hist_color_intersect(sky1,sky2) > 0.8:
        comp_score +=1

    if cp.lab_space_comp_percentage(sky1,sky2) < 0.2:
        comp_score +=1
    

    return comp_score

print(comp_img_2_img(image1dir,image2dir))

# %% [markdown]
# ## Feature to Feature

# %% [markdown]
# ### If person

# %%
import sktl_class as sk
import os 
def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0

    #Cant implicty grab the file extension
    baseImg1 = imgdir1 + "/" + imgdir1 + ".JPEG"
    baseImg2 = imgdir2 + "/" + imgdir2 + ".JPEG"

    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    people1Index = img1Df[img1Df['image'].str.split('_').str[0] == 'person'].index
    people2Index = img2Df[img2Df['image'].str.split('_').str[0] == 'person'].index

    for i in people1Index:
        personiimg=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[i]['image']
        personisktldata = {"image": personiimg, "skeltal_data": {"body_parts":  img2Df.iloc[i, 5:].to_dict()}}
        
        if not(all(not value for value in personisktldata['skeltal_data']['body_parts'].values())):
            
            personisktl = sk.Skeleton(personisktldata)
            if(not(personisktl.get_upper_cloth() or personisktl.get_upper_cloth())):
                personiUp = personisktl.get_upper_cloth()
                personiUpimage = 'person_i_Up.png'
                personiUp.save(personiUpimage)
                personiLow = personisktl.get_lower_cloth()
                personiLowImage = 'person_i_Low.png'
                personiLow.save(personiLowImage)

                for j in people2Index:
                    personjimg=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[j]['image']
                    personjsktldata = {"image": personjimg, "skeltal_data": {"body_parts":  img2Df.iloc[j, 5:].to_dict()}}
                    personjsktl = sk.Skeleton(personjsktldata)
                    
                    if(not(personjsktl.get_upper_cloth() or personjsktl.get_upper_cloth())):
                        personjUp = personjsktl.get_upper_cloth()
                        personjUpimage = 'person_j_Up.png'
                        personjUp.save(personjUpimage)
                        personjLow = personjsktl.get_lower_cloth()
                        personjLowImage = 'person_j_Low.png'
                        personjLow.save(personjLowImage)



                        if cp.lab_space_comp_percentage(personiUpimage,personjUpimage) < 0.2:
                            comp_score +=1
                        if cp.lab_space_comp_percentage(personiLowImage,personjLowImage) < 0.2:
                            comp_score +=1
                        
                        os.remove(personjUpimage)
                        os.remove(personjLowImage)

                os.remove(personiUpimage)
                os.remove(personiLowImage)
                        
        
    return comp_score 


comp_img_2_img(image1dir,image2dir)

# %% [markdown]
# ### Else Normal Object

# %% [markdown]
# #### Colour

# %%
def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0

    #Cant implicty grab the file extension
    baseImg1 = imgdir1 + "/" + imgdir1 + ".JPEG"
    baseImg2 = imgdir2 + "/" + imgdir2 + ".JPEG"

    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    for i1,obj1 in img1Df.iloc[:-1].iterrows():
        if obj1['label'] != 'person':
            for i2,obj2 in img2Df.iloc[:-1].iterrows():
                if obj1['label'] == obj2['label']:
                    objimg1=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[i1]['image']
                    objimg2=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[i2]['image']


                    if cp.get_distance(objimg1,objimg2) < 0.2:
                        comp_score +=1

                    if cp.hist_color_intersect(objimg1,objimg2) > 0.8:
                        comp_score +=1
                    # This takes ages
                    # if cp.lab_space_comp_percentage(objimg1,objimg2) < 0.2:
                    #     comp_score +=1

    return comp_score


comp_img_2_img(image1dir,image2dir)

# %% [markdown]
# #### Text

# %% [markdown]
# # Final Algo Function

# %%
def get_obj_placment(df,x):
    if(x == 0):
        return (0,(df.iloc[x]['label']),(df.iloc[x+1]['label']))
    elif (x == len(df)-1):
        return ((df.iloc[x-1]['label']),(df.iloc[x]['label']),0)
    else:
        return (df.iloc[x-1]['label'],(df.iloc[x]['label']),(df.iloc[x+1]['label']))


def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0

    #Cant implicty grab the file extension
    baseImg1 = imgdir1 + "/" + imgdir1 + ".JPEG"
    baseImg2 = imgdir2 + "/" + imgdir2 + ".JPEG"

    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    img1DfOrderedLablesAsc = img1Df.sort_values(by='label', ascending=True)['label']
    img2DfOrderedLablesAsc = img2Df.sort_values(by='label', ascending=True)['label']

    img1LabelAscCounts = img1DfOrderedLablesAsc.value_counts()
    img2LabelAscCounts = img2DfOrderedLablesAsc.value_counts()

    common_lables = img1LabelAscCounts.index.intersection(img2LabelAscCounts.index)

    for value in common_lables:
        count1 = img1LabelAscCounts[value]
        count2 = img2LabelAscCounts[value]
        if count1 == count2:
            comp_score += 1

    
    for i in range(0,len(img1Df)-1):
        for j in range(0,len(img2Df)-1):
            if get_obj_placment(img1Df,i) == get_obj_placment(img2Df,j):
                comp_score +=1
            elif get_obj_placment(img1Df,i) == get_obj_placment(img2Df,j)[::-1]:
                
                comp_score +=1

    sky1Index = img1Df[img1Df['image'].str.split('_').str[0] == 'sky'].index
    sky2Index = img2Df[img2Df['image'].str.split('_').str[0] == 'sky'].index


    skyimg1=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[sky1Index]['image']
    skyimg2=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[sky2Index]['image']
    sky1=skyimg1.values[0]
    sky2=skyimg2.values[0]


    ##Can always edit these later
    if cp.get_distance(sky1,sky2) < 0.2:
        comp_score +=1

    if cp.hist_color_intersect(sky1,sky2) > 0.8:
        comp_score +=1

    if cp.lab_space_comp_percentage(sky1,sky2) < 0.2:
        comp_score +=1

    people1Index = img1Df[img1Df['image'].str.split('_').str[0] == 'person'].index
    people2Index = img2Df[img2Df['image'].str.split('_').str[0] == 'person'].index

    for i in people1Index:
        personiimg=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[i]['image']
        personisktldata = {"image": personiimg, "skeltal_data": {"body_parts":  img2Df.iloc[i, 5:].to_dict()}}
        
        if not(all(not value for value in personisktldata['skeltal_data']['body_parts'].values())):
            
            personisktl = sk.Skeleton(personisktldata)
            if(not(personisktl.get_upper_cloth() or personisktl.get_lower_cloth())):
                personiUp = personisktl.get_upper_cloth()
                personiUpimage = 'person_i_Up.png'
                personiUp.save(personiUpimage)
                personiLow = personisktl.get_lower_cloth()
                personiLowImage = 'person_i_Low.png'
                personiLow.save(personiLowImage)

                for j in people2Index:
                    personjimg=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[j]['image']
                    personjsktldata = {"image": personjimg, "skeltal_data": {"body_parts":  img2Df.iloc[j, 5:].to_dict()}}
                    personjsktl = sk.Skeleton(personjsktldata)
                    
                    if(not(personjsktl.get_upper_cloth() or personjsktl.get_lower_cloth())):
                        personjUp = personjsktl.get_upper_cloth()
                        personjUpimage = 'person_j_Up.png'
                        personjUp.save(personjUpimage)
                        personjLow = personjsktl.get_lower_cloth()
                        personjLowImage = 'person_j_Low.png'
                        personjLow.save(personjLowImage)



                        if cp.lab_space_comp_percentage(personiUpimage,personjUpimage) < 0.2:
                            comp_score +=1
                        if cp.lab_space_comp_percentage(personiLowImage,personjLowImage) < 0.2:
                            comp_score +=1
                        
                        os.remove(personjUpimage)
                        os.remove(personjLowImage)

                os.remove(personiUpimage)
                os.remove(personiLowImage)
                
    for i1,obj1 in img1Df.iloc[:-1].iterrows():
        if obj1['label'] != 'person':
            for i2,obj2 in img2Df.iloc[:-1].iterrows():
                if obj1['label'] == obj2['label']:
                    objimg1=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[i1]['image']
                    objimg2=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[i2]['image']


                    if cp.get_distance(objimg1,objimg2) < 0.2:
                        comp_score +=1

                    if cp.hist_color_intersect(objimg1,objimg2) > 0.8:
                        comp_score +=1
                    # This takes ages
                    # if cp.lab_space_comp_percentage(objimg1,objimg2) < 0.2:
                    #     comp_score +=1

    return comp_score

# %% [markdown]
# # Comp Loop

# %%
import json

#Get list of all dirs in the images dir 

# List all entries in the directory
entries = os.listdir()

# Filter out the entries that are directories
imagefolders = [entry for entry in entries if os.path.isdir(os.path.join(entry))]

for i in imagefolders:
    for j in imagefolders:
        if i != j:
            comp_results = {
                'image1' : i,
                'image2' : j,
                'comp_score' : comp_img_2_img(i,j)
            }

with open('image_comparison.json', 'a') as f:
    json.dump(comp_results, f)

# %% [markdown]
# ## Create threshold for each feauter comp

# %% [markdown]
# ## Check the highest matching featuers

# %% [markdown]
# ## Check the average matching featuers

# %%
import json
import pandas as pd
import os
import colour_comp as cp
import sktl_class as sk
import PIL as Image

def check_dimensions_within_bounds(ref, new):
    # Get dimensions of both images
    width_ref, height_ref = ref.size
    width_new, height_new = new.size

    # Check if image b's dimensions are within the bounds of image a
    if width_new <= width_ref and height_new <= height_ref:
        return True
    else:
        return False
    
def get_obj_placement(df, x):
    if 0 < x < len(df) - 1:
        return (df.iloc[x-1]['label'], df.iloc[x]['label'], df.iloc[x+1]['label'])
    return None  



def comp_img_2_img(imgdir1,imgdir2):
    comp_score = 0
    occurences_score = 0
    placement_score = 0
    colour_score = 0
    person_score = 0

    comp_weight = 1
    occurences_weight = 1
    placement_weight =1
    colour_weight = 1
    person_weight =1  

    colour_distance_thres = 0.2
    colour_hist_thres = 0.8
    colour_lab_thres = 0.2


    img1Df = pd.read_json(imgdir1 + "/" + imgdir1 + "_feature_df.json")
    img2Df = pd.read_json(imgdir2 + "/" + imgdir2 + "_feature_df.json")

    img1DfOrderedLablesAsc = img1Df.sort_values(by='label', ascending=True)['label']
    img2DfOrderedLablesAsc = img2Df.sort_values(by='label', ascending=True)['label']

    img1LabelAscCounts = img1DfOrderedLablesAsc.value_counts()
    img2LabelAscCounts = img2DfOrderedLablesAsc.value_counts()

    common_lables = img1LabelAscCounts.index.intersection(img2LabelAscCounts.index)

    for value in common_lables:
        count1 = img1LabelAscCounts[value]
        count2 = img2LabelAscCounts[value]
        if count1 == count2:
            occurences_score +=1
            comp_score += 1

    

    # Why is wouldn't wokr
    for i in range(1, len(img1Df) - 1):
        if img1Df.iloc[i]['idNo'] != -1:
            img1_placement = get_obj_placement(img1Df, i)
            if img1_placement:
                for j in range(1, len(img2Df) - 1):
                    if img2Df.iloc[j]['idNo'] != -1:
                        img2_placement = get_obj_placement(img2Df, j)
                        if img1_placement == img2_placement and img1_placement != None and img2_placement !=None:
                            placement_score += 1
                            comp_score += 1
                        
    people1Index = img1Df[img1Df['image'].str.split('_').str[0] == 'person'].index
    people2Index = img2Df[img2Df['image'].str.split('_').str[0] == 'person'].index

    for i in people1Index:
        print("PERSON: " + img1Df.iloc[i]['image'] )

    for i in people1Index:
        personiimg=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[i]['image']
        personisktldata = {"image": personiimg, "skeltal_data": {"body_parts":  img1Df.iloc[i, 5:].to_dict()}}
        print(personisktldata) 
        if any(value is not None for value in personisktldata['skeltal_data']['body_parts'].values()):
            print("This passed")
            personisktl = sk.Skeleton(personisktldata)

###Upper#####
                        
            if(type(personisktl.get_upper_cloth()) is not type(None) and check_dimensions_within_bounds(Image.open(personiimg),personisktl.get_upper_cloth())):
                personiUp = personisktl.get_upper_cloth()
                personiUpimage = 'person_i_Up.png'
                print("\n Type: " + str(type(personiUp)) + "\n")
                try:
                    personiUp.save(personiUpimage)
                    print("\n" + imgdir1 + ":" + personiimg + " Upper \n")
                    personiUp.show()
                    print("\n")
                    for j in people2Index:
                        personjimg=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[j]['image']
                        personjsktldata = {"image": personjimg, "skeltal_data": {"body_parts":  img2Df.iloc[j, 5:].to_dict()}}
                        personjsktl = sk.Skeleton(personjsktldata)

                        ###People to pepole

                        if cp.lab_space_comp_percentage(personiimg,personjimg) < 0.2:
                                comp_score +=1
                                person_score +=1

                        if(type(personjsktl.get_upper_cloth()) is not type(None) and check_dimensions_within_bounds(Image.open(personjimg),personjsktl.get_upper_cloth())):
                            personjUp = personjsktl.get_upper_cloth()
                            personjUpimage = 'person_j_Up.png'
                            print("\n Type: " + str(type(personjUp)) + "\n")
                            try:
                                personjUp.save(personjUpimage)
                                print("\n" + imgdir2 + ":" + personjimg + " Upper \n")
                                personjUp.show()
                                print("\n")
                                if cp.lab_space_comp_percentage(personiUpimage,personjUpimage) < colour_lab_thres:
                                    comp_score +=1
                                    person_score +=1
                                
                                os.remove(personjUpimage)
                            except:
                                print(personjimg + "in up caused problem")

                    os.remove(personiUpimage)
                except:
                    print(personiimg + "in up caused problem")

####Lower####
            if(type(personisktl.get_lower_cloth()) is not type(None) and check_dimensions_within_bounds(Image.open(personiimg),personisktl.get_lower_cloth())):
                personiLow = personisktl.get_lower_cloth()
                personiLowImage = 'person_i_Low.png'
                print("\n Type: " + str(type(personiLow)) + "\n")
                try:
                    personiLow.save(personiLowImage)
                    print("\n" + imgdir1 + ":" + personiimg + " Lower \n")
                    personiLow.show()
                    print("\n")

                    for j in people2Index:
                        personjimg=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[j]['image']
                        personjsktldata = {"image": personjimg, "skeltal_data": {"body_parts":  img2Df.iloc[j, 5:].to_dict()}}
                        personjsktl = sk.Skeleton(personjsktldata)
                        if(type(personjsktl.get_lower_cloth()) is not type(None) and check_dimensions_within_bounds(Image.open(personjimg),personjsktl.get_lower_cloth())):
                            personjLow = personjsktl.get_lower_cloth()
                            personjLowImage = 'person_j_Low.png'
                            print("\n Type: " + str(type(personjLow)) + "\n")
                            try:
                                personjLow.save(personjLowImage)
                                print("\n" + imgdir2 + ":" + personjimg + " Lower \n")
                                personjLow.show()
                                print("\n")
                                if cp.lab_space_comp_percentage(personiLowImage,personjLowImage) < colour_lab_thres:
                                    comp_score +=1
                                    person_score +=1
                                
                                os.remove(personjLowImage)
                            except:
                                print(personjimg + "in low caused problem")


                    os.remove(personiLowImage)
                except:
                     print(personiimg + "in low caused problem")

                          
    for i1,obj1 in img1Df.iloc[:-1].iterrows():
        if obj1['label'] != 'person':
            for i2,obj2 in img2Df.iloc[:-1].iterrows():
                if obj1['label'] == obj2['label']:
                    objimg1=img1Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img1Df.iloc[-1]['image'].split('.')[0]  + "/" + img1Df.iloc[i1]['image']
                    objimg2=img2Df.iloc[-1]['image'].split('.')[0] + "/masks_" + img2Df.iloc[-1]['image'].split('.')[0]  + "/" + img2Df.iloc[i2]['image']


                    if cp.get_distance(objimg1,objimg2) < colour_distance_thres:
                        comp_score +=1
                        colour_score +=1

                    if cp.hist_color_intersect(objimg1,objimg2) > colour_hist_thres:
                        comp_score +=1
                        colour_score +=1
                    if cp.lab_space_comp_percentage(objimg1,objimg2) < 0.2:
                        comp_score +=1

    return [comp_score,occurences_score,placement_score,colour_score,person_score]


# #Get list of all dirs in the images dir 
os.chdir("../../images")
print(os.getcwd())

# List all entries in the directory
entries = os.listdir()

# Filter out the entries that are directories
imagefolders = [entry for entry in entries if os.path.isdir(os.path.join(entry))]

comp_data = []

print(imagefolders)

for i in range(len(imagefolders)):
     for j in range(i, len(imagefolders)):
            print('comparing :' + imagefolders[i] + " to " + imagefolders[j] )
            scores_array = comp_img_2_img(imagefolders[i],imagefolders[j])
            comp = {
                'image1' : imagefolders[i],
                'image2' : imagefolders[j],
                'comp_score' : scores_array[0],
                'occurnences_score': scores_array[1],
                'placement_score' : scores_array[2],
                'colour_score' : scores_array[3],
                'person_score' : scores_array[4]
            }
            comp_data.append(comp)



with open('image_comparison_rev.json', 'w') as f:
    json.dump(comp_data, f)


print(pd.read_json('image_comparison_rev.json'))
# Out:
# c:\Users\Ossia\Documents\SCCUIF\images
# ['IMG_2281', 'IMG_6543', 'IMG_6555', 'IMG_6576']
# comparing :IMG_2281 to IMG_2281
# PERSON: person_4.png
# PERSON: person_6.png
# PERSON: person_3.png
# PERSON: person_1.png
# {'image': 'IMG_2281/masks_IMG_2281/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 0.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_6.png', 'skeltal_data': {'body_parts': {'idNo': 1.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_1.png', 'skeltal_data': {'body_parts': {'idNo': 7.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# c:\Users\Ossia\Documents\SCCUIF\scripts\Algo\colour_comp.py:51: RuntimeWarning: invalid value encountered in double_scalars
#   scaled_distance = (np.average(distances) - np.min(distances)) / (np.max(distances) - np.min(distances))
# comparing :IMG_2281 to IMG_6543
# PERSON: person_4.png
# PERSON: person_6.png
# PERSON: person_3.png
# PERSON: person_1.png
# {'image': 'IMG_2281/masks_IMG_2281/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 0.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_6.png', 'skeltal_data': {'body_parts': {'idNo': 1.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_1.png', 'skeltal_data': {'body_parts': {'idNo': 7.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_2281 to IMG_6555
# PERSON: person_4.png
# PERSON: person_6.png
# PERSON: person_3.png
# PERSON: person_1.png
# {'image': 'IMG_2281/masks_IMG_2281/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 0.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_6.png', 'skeltal_data': {'body_parts': {'idNo': 1.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_1.png', 'skeltal_data': {'body_parts': {'idNo': 7.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_2281 to IMG_6576
# PERSON: person_4.png
# PERSON: person_6.png
# PERSON: person_3.png
# PERSON: person_1.png
# {'image': 'IMG_2281/masks_IMG_2281/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 0.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_6.png', 'skeltal_data': {'body_parts': {'idNo': 1.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_2281/masks_IMG_2281/person_1.png', 'skeltal_data': {'body_parts': {'idNo': 7.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'RHip': None, 'RKnee': None, 'RShoulder': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_6543 to IMG_6543
# PERSON: person_6.png
# PERSON: person_4.png
# PERSON: person_1.png
# PERSON: person_3.png
# PERSON: person_5.png
# PERSON: person_2.png
# {'image': 'IMG_6543/masks_IMG_6543/person_6.png', 'skeltal_data': {'body_parts': {'idNo': 2.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 3.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_1.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 5.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_5.png', 'skeltal_data': {'body_parts': {'idNo': 6.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_2.png', 'skeltal_data': {'body_parts': {'idNo': 8.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_6543 to IMG_6555
# PERSON: person_6.png
# PERSON: person_4.png
# PERSON: person_1.png
# PERSON: person_3.png
# PERSON: person_5.png
# PERSON: person_2.png
# {'image': 'IMG_6543/masks_IMG_6543/person_6.png', 'skeltal_data': {'body_parts': {'idNo': 2.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 3.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_1.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 5.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_5.png', 'skeltal_data': {'body_parts': {'idNo': 6.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_2.png', 'skeltal_data': {'body_parts': {'idNo': 8.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_6543 to IMG_6576
# PERSON: person_6.png
# PERSON: person_4.png
# PERSON: person_1.png
# PERSON: person_3.png
# PERSON: person_5.png
# PERSON: person_2.png
# {'image': 'IMG_6543/masks_IMG_6543/person_6.png', 'skeltal_data': {'body_parts': {'idNo': 2.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 3.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_1.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 5.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_5.png', 'skeltal_data': {'body_parts': {'idNo': 6.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6543/masks_IMG_6543/person_2.png', 'skeltal_data': {'body_parts': {'idNo': 8.0, 'LAnkle': None, 'LEar': None, 'LElbow': None, 'LEye': None, 'LHip': None, 'LKnee': None, 'LShoulder': None, 'LWrist': None, 'Neck': None, 'Nose': None, 'RAnkle': None, 'REar': None, 'RElbow': None, 'REye': None, 'RHip': None, 'RKnee': None, 'RShoulder': None, 'RWrist': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_6555 to IMG_6555
# PERSON: person_2.png
# PERSON: person_3.png
# PERSON: person_11.png
# PERSON: person_5.png
# PERSON: person_4.png
# PERSON: person_9.png
# PERSON: person_12.png
# PERSON: person_7.png
# PERSON: person_13.png
# PERSON: person_8.png
# {'image': 'IMG_6555/masks_IMG_6555/person_2.png', 'skeltal_data': {'body_parts': {'idNo': 1.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 2.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_11.png', 'skeltal_data': {'body_parts': {'idNo': 3.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_5.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 5.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_9.png', 'skeltal_data': {'body_parts': {'idNo': 6.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_12.png', 'skeltal_data': {'body_parts': {'idNo': 9.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_7.png', 'skeltal_data': {'body_parts': {'idNo': 10.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_13.png', 'skeltal_data': {'body_parts': {'idNo': 11.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_8.png', 'skeltal_data': {'body_parts': {'idNo': 12.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_6555 to IMG_6576
# PERSON: person_2.png
# PERSON: person_3.png
# PERSON: person_11.png
# PERSON: person_5.png
# PERSON: person_4.png
# PERSON: person_9.png
# PERSON: person_12.png
# PERSON: person_7.png
# PERSON: person_13.png
# PERSON: person_8.png
# {'image': 'IMG_6555/masks_IMG_6555/person_2.png', 'skeltal_data': {'body_parts': {'idNo': 1.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_3.png', 'skeltal_data': {'body_parts': {'idNo': 2.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_11.png', 'skeltal_data': {'body_parts': {'idNo': 3.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_5.png', 'skeltal_data': {'body_parts': {'idNo': 4.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_4.png', 'skeltal_data': {'body_parts': {'idNo': 5.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_9.png', 'skeltal_data': {'body_parts': {'idNo': 6.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_12.png', 'skeltal_data': {'body_parts': {'idNo': 9.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_7.png', 'skeltal_data': {'body_parts': {'idNo': 10.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_13.png', 'skeltal_data': {'body_parts': {'idNo': 11.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# {'image': 'IMG_6555/masks_IMG_6555/person_8.png', 'skeltal_data': {'body_parts': {'idNo': 12.0, 'LAnkle': None, 'LHip': None, 'LKnee': None, 'Neck': None, 'RAnkle': None, 'RHip': None, 'RKnee': None}}}
# This passed
# No Neck found
# No hips found
# comparing :IMG_6576 to IMG_6576
# PERSON: person_12.png
# {'image': 'IMG_6576/masks_IMG_6576/person_12.png', 'skeltal_data': {'body_parts': {'idNo': 8.0}}}
# This passed
# No Neck found
# No hips found
#      image1    image2  comp_score  occurnences_score  placement_score  \
# 0  IMG_2281  IMG_2281          42                 10                8
# 1  IMG_2281  IMG_6543          15                  5                0
# 2  IMG_2281  IMG_6555          26                  7                0
# 3  IMG_2281  IMG_6576          22                  4                0
# 4  IMG_6543  IMG_6543          40                  9               15
# 5  IMG_6543  IMG_6555          32                  5               19
# 6  IMG_6543  IMG_6576          22                  2                0
# 7  IMG_6555  IMG_6555          73                  9               43
# 8  IMG_6555  IMG_6576          23                  3                0
# 9  IMG_6576  IMG_6576         328                  9               43
#
#    colour_score  person_score
# 0            12             0
# 1             8             0
# 2            12             0
# 3            15             0
# 4             8             0
# 5             6             0
# 6            15             0
# 7            12             0
# 8            17             0
# 9           148             0

# %%
import pandas as pd
pd.read_json('image_comparison_rev.json')
# Out:
#      image1    image2  comp_score  placement_score  colour_score  person_score
# 0  IMG_2281  IMG_2281          42                8            12             0
# 1  IMG_2281  IMG_6543          15                0             8             0
# 2  IMG_2281  IMG_6555          26                0            12             0
# 3  IMG_2281  IMG_6576          22                0            15             0
# 4  IMG_6543  IMG_6543          40               15             8             0
# 5  IMG_6543  IMG_6555          32               19             6             0
# 6  IMG_6543  IMG_6576          22                0            15             0
# 7  IMG_6555  IMG_6555          73               43            12             0
# 8  IMG_6555  IMG_6576          23                0            17             0
# 9  IMG_6576  IMG_6576         328               43           148             0
